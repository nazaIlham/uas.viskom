# %% [markdown]
# <a href="https://colab.research.google.com/github/nazaIlham/uas.viskom/blob/main/warna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import file
import matplotlib.pyplot as plt
import numpy as np
import cv2
import matplotlib.pyplot as plt
import glob

from skimage.color import rgb2gray
from skimage.feature import local_binary_pattern

#membaca file

img = plt.imread('2.jpg')

#membuat plot histogram warna
fig, axs = plt.subplots(1, 3, figsize=(10, 5))
for i, color in enumerate(['red', 'green', 'blue']):
    axs[i].hist(img[..., i].ravel(), bins=256, color=color)
    axs[i].set_xlim([0, 256])
    axs[i].set_ylim([0, 10000])
    axs[i].set_title(color.upper())

#menampilkan hasil
plt.show()
